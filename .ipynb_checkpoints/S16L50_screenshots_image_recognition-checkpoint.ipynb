# %%
import pyautogui

# %%
pyautogui.screenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x960 at 0x7F23E8D050F0>

# %%
pyautogui.screenshot('screenshot_example.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x960 at 0x7F23E8A92BA8>

# %%
pyautogui.locateOnScreen('calc5.png')

# %% [markdown]
# It should return the coordinates of the number 5 with the image of the calculator
