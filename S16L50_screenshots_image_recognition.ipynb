# %%
import pyautogui

# %%
pyautogui.screenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x960 at 0x7F4FF9BB6780>

# %%
pyautogui.screenshot('screenshot_example.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x960 at 0x7F4FF9229B70>

# %%
pyautogui.locateOnScreen('calc5.png')
